# %%
import requests, time, pandas as pd

GQL_URL = "https://orchestrator.pgatour.com/graphql"
HEADERS = {"User-Agent":"Mozilla/5.0",
           "X-Api-Key":"da2-gsrx5bibzbb4njvhl7t37wqyl4",
           "Content-Type":"application/json"}

QUERY = """
query TournamentPastResults($tournamentPastResultsId: ID!, $year: Int) {
  tournamentPastResults(id: $tournamentPastResultsId, year: $year) {
    players {
      position
      total
      parRelativeScore
      player { id displayName }
      rounds { score parRelativeScore }
    }
  }
}
"""

def fetch_tournament_info_historical():
    all_tournaments = []
    for year in range(2010, 2026):
        payload = requests.get(f"https://data-api.pgatour.com/schedule/R/{year}?sort=ASC", timeout=30).json()
        for t in payload.get("tournaments", []):
            t["season_year"] = year
            all_tournaments.append(t)
    return pd.DataFrame(all_tournaments)

def fetch_tournament_results_historical():
    info_df = fetch_tournament_info_historical()

    name_map = (info_df[["tournamentId", "name"]]
                .dropna().drop_duplicates("tournamentId")
                .set_index("tournamentId")["name"].to_dict())

    tids = info_df["tournamentId"].dropna().drop_duplicates().astype(str).tolist()

    rows = []
    for tid in tids:
        yr_from_id = int(tid[1:5])
        year_param = int(f"{yr_from_id}0")   # 20250

        resp = requests.post(
        GQL_URL,
        headers=HEADERS,
        json={
            "query": QUERY,
            "operationName": "TournamentPastResults",
            "variables": {"tournamentPastResultsId": tid, "year": year_param},
        },
    ).json()

        if resp.get("errors"):
            print(f"ERROR: {tid} ({yr_from_id}) -> {resp['errors'][0].get('message')}")
            continue

        players = resp.get("data", {}).get("tournamentPastResults", {}).get("players", []) or []
        tname = name_map.get(tid)

        for p in players:
            player = p.get("player") or {}
            row = {
                "tournamentId": tid,
                "season_year": yr_from_id,
                "tournament_key": tname,
                "position": p.get("position"),
                "total": p.get("total"),
                "parRelativeScore": p.get("parRelativeScore"),
                "playerId": player.get("id"),
                "playerName": player.get("displayName"),
            }
            for i, rd in enumerate(p.get("rounds") or [], 1):
                row[f"r{i}_score"] = rd.get("score")
                row[f"r{i}_par"] = rd.get("parRelativeScore")
            rows.append(row)

        print(f"Done: {tid} ({yr_from_id}) {tname} players={len(players)}")
        time.sleep(0.15)

    return pd.DataFrame(rows)

df = fetch_tournament_results_historical()
# Out:
# Done: R2012016 (2012) Hyundai Tournament of Champions players=27
# Done: R2012006 (2012) Sony Open in Hawaii players=144
# Done: R2012002 (2012) Humana Challenge in partnership with the Clinton Foundation players=144
# Done: R2012004 (2012) Farmers Insurance Open players=156
# Done: R2012003 (2012) Waste Management Phoenix Open players=132
# Done: R2012005 (2012) AT&T Pebble Beach National Pro-Am players=156
# Done: R2012007 (2012) Northern Trust Open players=144
# Done: R2012470 (2012) World Golf Championships-Accenture Match Play Championship players=64
# Done: R2012457 (2012) Mayakoba Golf Classic players=132
# Done: R2012010 (2012) The Honda Classic players=144
# Done: R2012473 (2012) World Golf Championships-Cadillac Championship players=0
# Done: R2012483 (2012) Puerto Rico Open presented by seepuertorico.com players=132
# Done: R2012475 (2012) Transitions Championship players=144
# Done: R2012485 (2012) Tavistock Cup players=0
# Done: R2012009 (2012) Arnold Palmer Invitational presented by MasterCard players=120
# Done: R2012020 (2012) Shell Houston Open players=144
# Done: R2012014 (2012) Masters Tournament players=95
# Done: R2012012 (2012) RBC Heritage players=132
# Done: R2012041 (2012) Valero Texas Open players=156
# Done: R2012018 (2012) Zurich Classic of New Orleans players=156
# Done: R2012480 (2012) Wells Fargo Championship players=156
# Done: R2012011 (2012) THE PLAYERS Championship players=144
# Done: R2012019 (2012) HP Byron Nelson Championship players=156
# Done: R2012021 (2012) Crowne Plaza Invitational at Colonial players=123
# Done: R2012023 (2012) the Memorial Tournament presented by Nationwide Insurance players=120
# Done: R2012025 (2012) FedEx St. Jude Classic players=0
# Done: R2012026 (2012) U.S. Open players=156
# Done: R2012486 (2012) CVS Caremark Charity Classic players=0
# Done: R2012034 (2012) Travelers Championship players=156
# Done: R2012471 (2012) AT&T National players=0
# Done: R2012490 (2012) The Greenbrier Classic players=0
# Done: R2012030 (2012) John Deere Classic players=156
# Done: R2012100 (2012) The Open Championship players=156
# Done: R2012054 (2012) True South Classic players=131
# Done: R2012032 (2012) RBC Canadian Open players=156
# Done: R2012476 (2012) World Golf Championships-Bridgestone Invitational players=0
# Done: R2012472 (2012) Reno-Tahoe Open players=131
# Done: R2012033 (2012) PGA Championship players=156
# Done: R2012013 (2012) Wyndham Championship players=156
# Done: R2012027 (2012) The Barclays players=123
# Done: R2012505 (2012) Deutsche Bank Championship players=0
# Done: R2012028 (2012) BMW Championship players=70
# Done: R2012060 (2012) TOUR Championship by Coca-Cola players=30
# Done: R2012468 (2012) Ryder Cup players=24
# Done: R2012047 (2012) Justin Timberlake Shriners Hospitals for Children Open players=132
# Done: R2012464 (2012) Frys.com Open players=131
# Done: R2012493 (2012) The McGladrey Classic players=132
# Done: R2012504 (2012) PGA Grand Slam of Golf players=0
# Done: R2012494 (2012) CIMB Classic players=0
# Done: R2012489 (2012) World Golf Championships-HSBC Champions players=0
# Done: R2012045 (2012) Children's Miracle Network Hospitals Classic players=0
# Done: R2012509 (2012) Tyco Golf Skills Challenge players=0
# Done: R2012324 (2012) Wendy's 3-Tour Challenge players=0
# Done: R2012088 (2012) PGA TOUR Qualifying Tournament players=172
# Done: R2012478 (2012) World Challenge presented by Northwestern Mutual players=18
# Done: R2012058 (2012) Franklin Templeton Shootout players=24
# Done: R2013016 (2013) Hyundai Tournament of Champions players=30
# Done: R2013006 (2013) Sony Open in Hawaii players=144
# Done: R2013002 (2013) Humana Challenge in partnership with the Clinton Foundation players=156
# Done: R2013004 (2013) Farmers Insurance Open players=156
# Done: R2013003 (2013) Waste Management Phoenix Open players=132
# Done: R2013005 (2013) AT&T Pebble Beach National Pro-Am players=156
# Done: R2013007 (2013) Northern Trust Open players=144
# Done: R2013470 (2013) World Golf Championships-Accenture Match Play Championship players=64
# Done: R2013010 (2013) The Honda Classic players=144
# Done: R2013473 (2013) World Golf Championships-Cadillac Championship players=0
# Done: R2013483 (2013) Puerto Rico Open presented by seepuertorico.com players=132
# Done: R2013475 (2013) Tampa Bay Championship presented by EverBank players=156
# Done: R2013009 (2013) Arnold Palmer Invitational presented by MasterCard players=132
# Done: R2013485 (2013) Tavistock Cup players=0
# Done: R2013020 (2013) Shell Houston Open players=156
# Done: R2013041 (2013) Valero Texas Open players=156
# Done: R2013014 (2013) Masters Tournament players=93
# Done: R2013012 (2013) RBC Heritage players=144
# Done: R2013018 (2013) Zurich Classic of New Orleans players=156
# Done: R2013480 (2013) Wells Fargo Championship players=156
# Done: R2013011 (2013) THE PLAYERS Championship players=145
# Done: R2013019 (2013) HP Byron Nelson Championship players=156
# Done: R2013021 (2013) Crowne Plaza Invitational at Colonial players=136
# Done: R2013023 (2013) the Memorial Tournament presented by Nationwide Insurance players=120
# Done: R2013025 (2013) FedEx St. Jude Classic players=0
# Done: R2013026 (2013) U.S. Open players=156
# Done: R2013034 (2013) Travelers Championship players=156
# Done: R2013486 (2013) CVS Caremark Charity Classic players=0
# Done: R2013471 (2013) AT&T National players=0
# Done: R2013490 (2013) The Greenbrier Classic players=0
# Done: R2013030 (2013) John Deere Classic players=156
# Done: R2013100 (2013) The Open Championship players=156
# Done: R2013054 (2013) Sanderson Farms Championship players=129
# Done: R2013032 (2013) RBC Canadian Open players=155
# Done: R2013476 (2013) World Golf Championships-Bridgestone Invitational players=0
# Done: R2013472 (2013) Reno-Tahoe Open players=132
# Done: R2013033 (2013) PGA Championship players=156
# Done: R2013013 (2013) Wyndham Championship players=156
# Done: R2013027 (2013) The Barclays players=123
# Done: R2013505 (2013) Deutsche Bank Championship players=0
# Done: R2013028 (2013) BMW Championship players=70
# Done: R2013060 (2013) TOUR Championship by Coca-Cola players=30
# Done: R2013500 (2013) Presidents Cup players=24
# Done: R2014464 (2014) Frys.com Open players=132
# Done: R2014504 (2014) PGA Grand Slam of Golf players=0
# Done: R2014047 (2014) Shriners Hospitals for Children Open players=132
# Done: R2014494 (2014) CIMB Classic players=0
# Done: R2014489 (2014) World Golf Championships-HSBC Champions players=0
# Done: R2014493 (2014) The McGladrey Classic players=132
# Done: R2014324 (2014) Wendy's 3-Tour Challenge players=0
# Done: R2014457 (2014) OHL Classic at Mayakoba players=132
# Done: R2014169 (2014) ISPS HANDA World Cup of Golf players=0
# Done: R2014478 (2014) Northwestern Mutual World Challenge players=18
# Done: R2014058 (2014) Franklin Templeton Shootout players=24
# Done: R2014016 (2014) Hyundai Tournament of Champions players=30
# Done: R2014006 (2014) Sony Open in Hawaii players=144
# Done: R2014002 (2014) Humana Challenge in partnership with the Clinton Foundation players=156
# Done: R2014004 (2014) Farmers Insurance Open players=156
# Done: R2014003 (2014) Waste Management Phoenix Open players=132
# Done: R2014005 (2014) AT&T Pebble Beach National Pro-Am players=156
# Done: R2014007 (2014) Northern Trust Open players=144
# Done: R2014470 (2014) World Golf Championships-Accenture Match Play Championship players=64
# Done: R2014010 (2014) The Honda Classic players=144
# Done: R2014473 (2014) World Golf Championships-Cadillac Championship players=0
# Done: R2014483 (2014) Puerto Rico Open presented by seepuertorico.com players=132
# Done: R2014475 (2014) Valspar Championship players=144
# Done: R2014009 (2014) Arnold Palmer Invitational presented by MasterCard players=120
# Done: R2014041 (2014) Valero Texas Open players=144
# Done: R2014020 (2014) Shell Houston Open players=144
# Done: R2014014 (2014) Masters Tournament players=97
# Done: R2014012 (2014) RBC Heritage players=132
# Done: R2014018 (2014) Zurich Classic of New Orleans players=156
# Done: R2014480 (2014) Wells Fargo Championship players=156
# Done: R2014011 (2014) THE PLAYERS Championship players=144
# Done: R2014019 (2014) HP Byron Nelson Championship players=156
# Done: R2014021 (2014) Crowne Plaza Invitational at Colonial players=123
# Done: R2014023 (2014) the Memorial Tournament presented by Nationwide Insurance players=120
# Done: R2014025 (2014) FedEx St. Jude Classic players=0
# Done: R2014026 (2014) U.S. Open players=156
# Done: R2014034 (2014) Travelers Championship players=156
# Done: R2014486 (2014) CVS Caremark Charity Classic players=0
# Done: R2014471 (2014) Quicken Loans National players=0
# Done: R2014490 (2014) The Greenbrier Classic players=0
# Done: R2014030 (2014) John Deere Classic players=155
# Done: R2014100 (2014) The Open Championship players=156
# Done: R2014032 (2014) RBC Canadian Open players=156
# Done: R2014476 (2014) World Golf Championships-Bridgestone Invitational players=0
# Done: R2014472 (2014) Barracuda Championship players=132
# Done: R2014033 (2014) PGA Championship players=156
# Done: R2014013 (2014) Wyndham Championship players=156
# Done: R2014027 (2014) The Barclays players=122
# Done: R2014505 (2014) Deutsche Bank Championship players=0
# Done: R2014028 (2014) BMW Championship players=69
# Done: R2014060 (2014) TOUR Championship by Coca-Cola players=29
# Done: R2014468 (2014) Ryder Cup players=24
# Done: R2015464 (2015) Frys.com Open players=144
# Done: R2015504 (2015) PGA Grand Slam of Golf players=0
# Done: R2015047 (2015) Shriners Hospitals for Children Open players=144
# Done: R2015493 (2015) The McGladrey Classic players=132
# Done: R2015494 (2015) CIMB Classic players=0
# Done: R2015489 (2015) World Golf Championships-HSBC Champions players=0
# Done: R2015054 (2015) Sanderson Farms Championship players=132
# Done: R2015457 (2015) OHL Classic at Mayakoba players=132
# Done: R2015478 (2015) Hero World Challenge players=18
# Done: R2015058 (2015) Franklin Templeton Shootout players=24
# Done: R2015016 (2015) Hyundai Tournament of Champions players=34
# Done: R2015006 (2015) Sony Open in Hawaii players=144
# Done: R2015002 (2015) Humana Challenge in partnership with the Clinton Foundation players=156
# Done: R2015003 (2015) Waste Management Phoenix Open players=132
# Done: R2015004 (2015) Farmers Insurance Open players=156
# Done: R2015005 (2015) AT&T Pebble Beach National Pro-Am players=156
# Done: R2015007 (2015) Northern Trust Open players=144
# Done: R2015010 (2015) The Honda Classic players=144
# Done: R2015473 (2015) World Golf Championships-Cadillac Championship players=0
# Done: R2015483 (2015) Puerto Rico Open players=132
# Done: R2015475 (2015) Valspar Championship players=144
# Done: R2015009 (2015) Arnold Palmer Invitational presented by MasterCard players=120
# Done: R2015041 (2015) Valero Texas Open players=144
# Done: R2015020 (2015) Shell Houston Open players=144
# Done: R2015014 (2015) Masters Tournament players=97
# Done: R2015012 (2015) RBC Heritage players=132
# Done: R2015018 (2015) Zurich Classic of New Orleans players=156
# Done: R2015470 (2015) World Golf Championships-Cadillac Match Play players=64
# Done: R2015011 (2015) THE PLAYERS Championship players=144
# Done: R2015480 (2015) Wells Fargo Championship players=156
# Done: R2015021 (2015) Crowne Plaza Invitational at  Colonial players=122
# Done: R2015019 (2015) AT&T Byron Nelson players=156
# Done: R2015023 (2015) the Memorial Tournament presented by Nationwide players=120
# Done: R2015025 (2015) FedEx St. Jude Classic players=0
# Done: R2015026 (2015) U.S. Open players=156
# Done: R2015034 (2015) Travelers Championship players=156
# Done: R2015486 (2015) CVS Health Charity Classic players=0
# Done: R2015490 (2015) The Greenbrier Classic players=0
# Done: R2015030 (2015) John Deere Classic players=156
# Done: R2015100 (2015) The Open Championship players=156
# Done: R2015518 (2015) Barbasol Championship players=130
# Done: R2015032 (2015) RBC Canadian Open players=156
# Done: R2015471 (2015) Quicken Loans National players=0
# Done: R2015476 (2015) World Golf Championships-Bridgestone Invitational players=0
# Done: R2015472 (2015) Barracuda Championship players=132
# Done: R2015033 (2015) PGA Championship players=156
# Done: R2015013 (2015) Wyndham Championship players=156
# Done: R2015027 (2015) The Barclays players=120
# Done: R2015505 (2015) Deutsche Bank Championship players=0
# Done: R2015028 (2015) BMW Championship players=70
# Done: R2015060 (2015) TOUR Championship by Coca-Cola players=29
# Done: R2015500 (2015) Presidents Cup players=24
# Done: R2016464 (2016) Frys.com Open players=144
# Done: R2016047 (2016) Shriners Hospitals for Children Open players=144
# Done: R2016494 (2016) CIMB Classic players=0
# Done: R2016489 (2016) World Golf Championships-HSBC Champions players=0
# Done: R2016054 (2016) Sanderson Farms Championship players=131
# Done: R2016457 (2016) OHL Classic at Mayakoba players=132
# Done: R2016493 (2016) The RSM Classic players=156
# Done: R2016478 (2016) Hero World Challenge players=18
# Done: R2016058 (2016) Franklin Templeton Shootout players=24
# Done: R2016016 (2016) Hyundai Tournament of Champions players=32
# Done: R2016006 (2016) Sony Open in Hawaii players=144
# Done: R2016002 (2016) CareerBuilder Challenge in partnership with the Clinton Foundation players=156
# Done: R2016004 (2016) Farmers Insurance Open players=156
# Done: R2016003 (2016) Waste Management Phoenix Open players=132
# Done: R2016005 (2016) AT&T Pebble Beach Pro-Am players=156
# Done: R2016007 (2016) Northern Trust Open players=144
# Done: R2016010 (2016) The Honda Classic players=144
# Done: R2016473 (2016) World Golf Championships-Cadillac Championship players=0
# Done: R2016475 (2016) Valspar Championship players=144
# Done: R2016009 (2016) Arnold Palmer Invitational presented by MasterCard players=120
# Done: R2016470 (2016) World Golf Championships-Dell Match Play players=64
# Done: R2016483 (2016) Puerto Rico Open at Coco Beach players=132
# Done: R2016020 (2016) Shell Houston Open players=144
# Done: R2016014 (2016) Masters Tournament players=89
# Done: R2016012 (2016) RBC Heritage players=132
# Done: R2016041 (2016) Valero Texas Open players=156
# Done: R2016018 (2016) Zurich Classic of New Orleans players=156
# Done: R2016480 (2016) Wells Fargo Championship players=156
# Done: R2016011 (2016) THE PLAYERS Championship players=144
# Done: R2016019 (2016) AT&T Byron Nelson players=156
# Done: R2016021 (2016) DEAN & DELUCA Invitational players=121
# Done: R2016023 (2016) the Memorial Tournament presented by Nationwide players=120
# Done: R2016025 (2016) FedEx St. Jude Classic players=0
# Done: R2016026 (2016) U.S. Open players=156
# Done: R2016471 (2016) Quicken Loans National players=0
# Done: R2016486 (2016) CVS Health Charity Classic players=0
# Done: R2016476 (2016) World Golf Championships-Bridgestone Invitational players=0
# Done: R2016472 (2016) Barracuda Championship players=132
# Done: R2016100 (2016) The Open Championship players=156
# Done: R2016518 (2016) Barbasol Championship players=132
# Done: R2016032 (2016) RBC Canadian Open players=156
# Done: R2016033 (2016) PGA Championship players=156
# Done: R2016034 (2016) Travelers Championship players=156
# Done: R2016519 (2016) Olympic Men's Golf Competition players=60
# Done: R2016030 (2016) John Deere Classic players=156
# Done: R2016013 (2016) Wyndham Championship players=156
# Done: R2016027 (2016) The Barclays players=120
# Done: R2016505 (2016) Deutsche Bank Championship players=0
# Done: R2016028 (2016) BMW Championship players=69
# Done: R2016060 (2016) TOUR Championship players=30
# Done: R2016468 (2016) Ryder Cup players=24
# Done: R2017464 (2017) Safeway Open players=144
# Done: R2017494 (2017) CIMB Classic players=0
# Done: R2017489 (2017) World Golf Championships-HSBC Champions players=0
# Done: R2017054 (2017) Sanderson Farms Championship players=132
# Done: R2017047 (2017) Shriners Hospitals for Children Open players=144
# Done: R2017457 (2017) OHL Classic at Mayakoba players=132
# Done: R2017493 (2017) The RSM Classic players=156
# Done: R2017169 (2017) ISPS HANDA World Cup of Golf players=0
# Done: R2017478 (2017) Hero World Challenge players=18
# Done: R2017058 (2017) Franklin Templeton Shootout players=24
# Done: R2017016 (2017) SBS Tournament of Champions players=32
# Done: R2017006 (2017) Sony Open in Hawaii players=144
# Done: R2017002 (2017) CareerBuilder Challenge players=156
# Done: R2017004 (2017) Farmers Insurance Open players=156
# Done: R2017003 (2017) Waste Management Phoenix Open players=132
# Done: R2017005 (2017) AT&T Pebble Beach Pro-Am players=156
# Done: R2017007 (2017) Genesis Open players=144
# Done: R2017010 (2017) The Honda Classic players=144
# Done: R2017473 (2017) World Golf Championships-Mexico Championship players=0
# Done: R2017475 (2017) Valspar Championship players=144
# Done: R2017009 (2017) Arnold Palmer Invitational presented by Mastercard players=120
# Done: R2017470 (2017) World Golf Championships-Dell Technologies Match Play players=64
# Done: R2017483 (2017) Puerto Rico Open players=132
# Done: R2017020 (2017) Shell Houston Open players=144
# Done: R2017014 (2017) Masters Tournament players=93
# Done: R2017012 (2017) RBC Heritage players=132
# Done: R2017041 (2017) Valero Texas Open players=156
# Done: R2017018 (2017) Zurich Classic of New Orleans players=0
# Done: R2017480 (2017) Wells Fargo Championship players=156
# Done: R2017011 (2017) THE PLAYERS Championship players=145
# Done: R2017019 (2017) AT&T Byron Nelson players=156
# Done: R2017021 (2017) DEAN & DELUCA Invitational players=121
# Done: R2017023 (2017) the Memorial Tournament presented by Nationwide players=120
# Done: R2017025 (2017) FedEx St. Jude Classic players=0
# Done: R2017026 (2017) U.S. Open players=156
# Done: R2017486 (2017) CVS Health Charity Classic players=0
# Done: R2017034 (2017) Travelers Championship players=156
# Done: R2017471 (2017) Quicken Loans National players=0
# Done: R2017490 (2017) The Greenbrier Classic players=0
# Done: R2017030 (2017) John Deere Classic players=156
# Done: R2017100 (2017) The Open Championship players=156
# Done: R2017518 (2017) Barbasol Championship players=132
# Done: R2017032 (2017) RBC Canadian Open players=156
# Done: R2017476 (2017) World Golf Championships-Bridgestone Invitational players=0
# Done: R2017472 (2017) Barracuda Championship players=133
# Done: R2017033 (2017) PGA Championship players=156
# Done: R2017013 (2017) Wyndham Championship players=156
# Done: R2017027 (2017) THE NORTHERN TRUST players=120
# Done: R2017505 (2017) Dell Technologies Championship players=0
# Done: R2017028 (2017) BMW Championship players=70
# Done: R2017060 (2017) TOUR Championship players=30
# Done: R2017500 (2017) Presidents Cup players=24
# Done: R2018464 (2018) Safeway Open players=144
# Done: R2018494 (2018) CIMB Classic players=0
# Done: R2018521 (2018) THE CJ CUP @ NINE BRIDGES players=78
# Done: R2018489 (2018) World Golf Championships-HSBC Champions players=0
# Done: R2018054 (2018) Sanderson Farms Championship players=132
# Done: R2018047 (2018) Shriners Hospitals for Children Open players=144
# Done: R2018457 (2018) OHL Classic at Mayakoba players=132
# Done: R2018493 (2018) The RSM Classic players=156
# Done: R2018478 (2018) Hero World Challenge players=18
# Done: R2018058 (2018) QBE Shootout players=24
# Done: R2018016 (2018) Sentry Tournament of Champions players=34
# Done: R2018006 (2018) Sony Open in Hawaii players=144
# Done: R2018002 (2018) CareerBuilder Challenge players=156
# Done: R2018004 (2018) Farmers Insurance Open players=156
# Done: R2018003 (2018) Waste Management Phoenix Open players=132
# Done: R2018005 (2018) AT&T Pebble Beach Pro-Am players=156
# Done: R2018007 (2018) Genesis Open players=144
# Done: R2018010 (2018) The Honda Classic players=144
# Done: R2018473 (2018) World Golf Championships-Mexico Championship players=0
# Done: R2018523 (2018) Puerto Rico Open Charity Day players=0
# Done: R2018475 (2018) Valspar Championship players=144
# Done: R2018009 (2018) Arnold Palmer Invitational presented by Mastercard players=120
# Done: R2018470 (2018) World Golf Championships-Dell Technologies Match Play players=64
# Done: R2018522 (2018) Corales Puntacana Resort & Club Championship players=132
# Done: R2018020 (2018) Houston Open players=144
# Done: R2018014 (2018) Masters Tournament players=87
# Done: R2018012 (2018) RBC Heritage players=132
# Done: R2018041 (2018) Valero Texas Open players=156
# Done: R2018018 (2018) Zurich Classic of New Orleans players=0
# Done: R2018480 (2018) Wells Fargo Championship players=156
# Done: R2018011 (2018) THE PLAYERS Championship players=144
# Done: R2018019 (2018) AT&T Byron Nelson players=156
# Done: R2018021 (2018) Fort Worth Invitational players=121
# Done: R2018023 (2018) the Memorial Tournament presented by Nationwide players=120
# Done: R2018025 (2018) FedEx St. Jude Classic players=0
# Done: R2018026 (2018) U.S. Open players=156
# Done: R2018034 (2018) Travelers Championship players=156
# Done: R2018486 (2018) CVS Health Charity Classic players=0
# Done: R2018471 (2018) Quicken Loans National players=0
# Done: R2018490 (2018) A Military Tribute at The Greenbrier players=0
# Done: R2018030 (2018) John Deere Classic players=156
# Done: R2018100 (2018) The Open Championship players=156
# Done: R2018518 (2018) Barbasol Championship players=132
# Done: R2018032 (2018) RBC Canadian Open players=155
# Done: R2018476 (2018) World Golf Championships-Bridgestone Invitational players=0
# Done: R2018472 (2018) Barracuda Championship players=132
# Done: R2018033 (2018) PGA Championship players=156
# Done: R2018013 (2018) Wyndham Championship players=156
# Done: R2018027 (2018) THE NORTHERN TRUST players=119
# Done: R2018505 (2018) Dell Technologies Championship players=0
# Done: R2018028 (2018) BMW Championship players=69
# Done: R2018060 (2018) TOUR Championship players=30
# Done: R2018468 (2018) Ryder Cup players=24
# Done: R2019464 (2019) Safeway Open players=144
# Done: R2019494 (2019) CIMB Classic players=0
# Done: R2019521 (2019) THE CJ CUP @ NINE BRIDGES players=78
# Done: R2019489 (2019) World Golf Championships-HSBC Champions players=0
# Done: R2019054 (2019) Sanderson Farms Championship players=132
# Done: R2019047 (2019) Shriners Hospitals for Children Open players=132
# Done: R2019457 (2019) Mayakoba Golf Classic players=132
# Done: R2019493 (2019) The RSM Classic players=156
# Done: R2019169 (2019) ISPS Handa Melbourne World Cup of Golf players=0
# Done: R2019526 (2019) Tiger vs. Phil players=0
# Done: R2019478 (2019) Hero World Challenge players=18
# Done: R2019058 (2019) QBE Shootout players=24
# Done: R2019016 (2019) Sentry Tournament of Champions players=33
# Done: R2019006 (2019) Sony Open in Hawaii players=144
# Done: R2019002 (2019) Desert Classic players=156
# Done: R2019004 (2019) Farmers Insurance Open players=156
# Done: R2019003 (2019) Waste Management Phoenix Open players=132
# Done: R2019005 (2019) AT&T Pebble Beach Pro-Am players=156
# Done: R2019007 (2019) Genesis Open players=144
# Done: R2019473 (2019) World Golf Championships-Mexico Championship players=0
# Done: R2019483 (2019) Puerto Rico Open players=132
# Done: R2019010 (2019) The Honda Classic players=144
# Done: R2019009 (2019) Arnold Palmer Invitational presented by Mastercard players=123
# Done: R2019011 (2019) THE PLAYERS Championship players=144
# Done: R2019475 (2019) Valspar Championship players=144
# Done: R2019470 (2019) World Golf Championships-Dell Technologies Match Play players=64
# Done: R2019522 (2019) Corales Puntacana Resort & Club Championship players=132
# Done: R2019041 (2019) Valero Texas Open players=144
# Done: R2019014 (2019) Masters Tournament players=87
# Done: R2019012 (2019) RBC Heritage players=132
# Done: R2019018 (2019) Zurich Classic of New Orleans players=0
# Done: R2019480 (2019) Wells Fargo Championship players=156
# Done: R2019019 (2019) AT&T Byron Nelson players=156
# Done: R2019033 (2019) PGA Championship players=156
# Done: R2019021 (2019) Charles Schwab Challenge players=122
# Done: R2019023 (2019) the Memorial Tournament presented by Nationwide players=120
# Done: R2019032 (2019) RBC Canadian Open players=156
# Done: R2019026 (2019) U.S. Open players=156
# Done: R2019034 (2019) Travelers Championship players=156
# Done: R2019486 (2019) CVS Health Charity Classic players=0
# Done: R2019524 (2019) Rocket Mortgage Classic players=156
# Done: R2019525 (2019) 3M Open players=156
# Done: R2019030 (2019) John Deere Classic players=156
# Done: R2019100 (2019) The Open Championship players=156
# Done: R2019518 (2019) Barbasol Championship players=132
# Done: R2019476 (2019) World Golf Championships-FedEx St. Jude Invitational players=0
# Done: R2019472 (2019) Barracuda Championship players=131
# Done: R2019013 (2019) Wyndham Championship players=156
# Done: R2019027 (2019) THE NORTHERN TRUST players=121
# Done: R2019028 (2019) BMW Championship players=69
# Done: R2019060 (2019) TOUR Championship players=30
# Done: R2020490 (2020) A Military Tribute at The Greenbrier players=0
# Done: R2020054 (2020) Sanderson Farms Championship players=156
# Done: R2020464 (2020) Safeway Open players=144
# Done: R2020047 (2020) Shriners Hospitals for Children Open players=144
# Done: R2020020 (2020) Houston Open players=144
# Done: R2020521 (2020) THE CJ CUP @ NINE BRIDGES players=78
# Done: R2020530 (2020) MGM Resorts The Challenge: Japan Skins players=0
# Done: R2020527 (2020) ZOZO CHAMPIONSHIP players=78
# Done: R2020489 (2020) World Golf Championships-HSBC Champions players=0
# Done: R2020528 (2020) Bermuda Championship players=120
# Done: R2020457 (2020) Mayakoba Golf Classic players=132
# Done: R2020493 (2020) The RSM Classic players=156
# Done: R2020478 (2020) Hero World Challenge players=18
# Done: R2020500 (2020) Presidents Cup players=0
# Done: R2020058 (2020) QBE Shootout players=24
# Done: R2020016 (2020) Sentry Tournament of Champions players=34
# Done: R2020006 (2020) Sony Open in Hawaii players=144
# Done: R2020002 (2020) The American Express players=156
# Done: R2020004 (2020) Farmers Insurance Open players=156
# Done: R2020003 (2020) Waste Management Phoenix Open players=132
# Done: R2020005 (2020) AT&T Pebble Beach Pro-Am players=156
# Done: R2020007 (2020) The Genesis Invitational players=120
# Done: R2020473 (2020) World Golf Championships-Mexico Championship players=0
# Done: R2020483 (2020) Puerto Rico Open players=120
# Done: R2020010 (2020) The Honda Classic players=144
# Done: R2020009 (2020) Arnold Palmer Invitational presented by Mastercard players=121
# Done: R2020531 (2020) TaylorMade Driving Relief players=0
# Done: R2020532 (2020) Capital One's The Match: Champions for Charity players=0
# Done: R2020021 (2020) Charles Schwab Challenge players=148
# Done: R2020012 (2020) RBC Heritage players=151
# Done: R2020034 (2020) Travelers Championship players=156
# Done: R2020524 (2020) Rocket Mortgage Classic players=157
# Done: R2020533 (2020) Workday Charity Open players=0
# Done: R2020023 (2020) the Memorial Tournament presented by Nationwide players=131
# Done: R2020525 (2020) 3M Open players=156
# Done: R2020476 (2020) World Golf Championships-FedEx St. Jude Invitational players=0
# Done: R2020472 (2020) Barracuda Championship players=131
# Done: R2020033 (2020) PGA Championship players=156
# Done: R2020013 (2020) Wyndham Championship players=156
# Done: R2020027 (2020) THE NORTHERN TRUST players=123
# Done: R2020028 (2020) BMW Championship players=69
# Done: R2020060 (2020) TOUR Championship players=30
# Done: R2021464 (2021) Safeway Open players=156
# Done: R2021026 (2021) U.S. Open (2020) players=144
# Done: R2021522 (2021) Corales Puntacana Resort & Club Championship (2020) players=144
# Done: R2021054 (2021) Sanderson Farms Championship players=144
# Done: R2021047 (2021) Shriners Hospitals for Children Open players=144
# Done: R2021521 (2021) THE CJ CUP @ SHADOW CREEK players=78
# Done: R2021527 (2021) ZOZO CHAMPIONSHIP @ SHERWOOD players=78
# Done: R2021528 (2021) Bermuda Championship players=132
# Done: R2021020 (2021) Vivint Houston Open players=132
# Done: R2021014 (2021) Masters Tournament (2020) players=92
# Done: R2021493 (2021) The RSM Classic players=156
# Done: R2021457 (2021) Mayakoba Golf Classic presented by UNIFIN players=132
# Done: R2021058 (2021) QBE Shootout players=24
# Done: R2021016 (2021) Sentry Tournament of Champions players=42
# Done: R2021006 (2021) Sony Open in Hawaii players=144
# Done: R2021002 (2021) The American Express players=156
# Done: R2021004 (2021) Farmers Insurance Open players=156
# Done: R2021003 (2021) Waste Management Phoenix Open players=132
# Done: R2021005 (2021) AT&T Pebble Beach Pro-Am players=156
# Done: R2021007 (2021) The Genesis Invitational players=120
# Done: R2021473 (2021) World Golf Championships-Workday Championship at The Concession players=0
# Done: R2021483 (2021) Puerto Rico Open players=132
# Done: R2021009 (2021) Arnold Palmer Invitational presented by Mastercard players=123
# Done: R2021011 (2021) THE PLAYERS Championship players=154
# Done: R2021010 (2021) The Honda Classic players=144
# Done: R2021470 (2021) World Golf Championships-Dell Technologies Match Play players=64
# Done: R2021534 (2021) Corales Puntacana Resort & Club Championship (2021) players=0
# Done: R2021041 (2021) Valero Texas Open players=144
# Done: R2021536 (2021) Masters Tournament (2021) players=92
# Done: R2021012 (2021) RBC Heritage players=134
# Done: R2021018 (2021) Zurich Classic of New Orleans players=0
# Done: R2021475 (2021) Valspar Championship players=156
# Done: R2021480 (2021) Wells Fargo Championship players=156
# Done: R2021019 (2021) AT&T Byron Nelson players=156
# Done: R2021033 (2021) PGA Championship players=156
# Done: R2021021 (2021) Charles Schwab Challenge players=121
# Done: R2021023 (2021) the Memorial Tournament presented by Nationwide players=120
# Done: R2021538 (2021) Palmetto Championship at Congaree players=156
# Done: R2021535 (2021) U.S. Open (2021) players=144
# Done: R2021034 (2021) Travelers Championship players=156
# Done: R2021524 (2021) Rocket Mortgage Classic players=156
# Done: R2021030 (2021) John Deere Classic players=156
# Done: R2021100 (2021) The Open Championship players=156
# Done: R2021518 (2021) Barbasol Championship players=132
# Done: R2021525 (2021) 3M Open players=156
# Done: R2021519 (2021) Olympic Men's Golf Competition players=60
# Done: R2021476 (2021) World Golf Championships-FedEx St. Jude Invitational players=0
# Done: R2021472 (2021) Barracuda Championship players=132
# Done: R2021013 (2021) Wyndham Championship players=156
# Done: R2021027 (2021) THE NORTHERN TRUST players=123
# Done: R2021028 (2021) BMW Championship players=69
# Done: R2021060 (2021) TOUR Championship players=30
# Done: R2022464 (2022) Fortinet Championship players=156
# Done: R2022468 (2022) Ryder Cup players=0
# Done: R2022054 (2022) Sanderson Farms Championship players=144
# Done: R2022047 (2022) Shriners Children's Open players=144
# Done: R2022521 (2022) THE CJ CUP @ SUMMIT players=78
# Done: R2022527 (2022) ZOZO CHAMPIONSHIP players=78
# Done: R2022528 (2022) Butterfield Bermuda Championship players=126
# Done: R2022457 (2022) World Wide Technology Championship at Mayakoba players=132
# Done: R2022020 (2022) Hewlett Packard Enterprise Houston Open players=132
# Done: R2022493 (2022) The RSM Classic players=156
# Done: R2022478 (2022) Hero World Challenge players=20
# Done: R2022058 (2022) QBE Shootout players=24
# Done: R2022016 (2022) Sentry Tournament of Champions players=38
# Done: R2022006 (2022) Sony Open in Hawaii players=144
# Done: R2022002 (2022) The American Express players=156
# Done: R2022004 (2022) Farmers Insurance Open players=156
# Done: R2022005 (2022) AT&T Pebble Beach Pro-Am players=156
# Done: R2022003 (2022) WM Phoenix Open players=132
# Done: R2022007 (2022) The Genesis Invitational players=120
# Done: R2022010 (2022) The Honda Classic players=144
# Done: R2022009 (2022) Arnold Palmer Invitational presented by Mastercard players=120
# Done: R2022483 (2022) Puerto Rico Open players=120
# Done: R2022011 (2022) THE PLAYERS Championship players=144
# Done: R2022475 (2022) Valspar Championship players=144
# Done: R2022470 (2022) World Golf Championships-Dell Technologies Match Play players=64
# Done: R2022522 (2022) Corales Puntacana Championship players=120
# Done: R2022041 (2022) Valero Texas Open players=144
# Done: R2022014 (2022) Masters Tournament players=90
# Done: R2022012 (2022) RBC Heritage players=132
# Done: R2022018 (2022) Zurich Classic of New Orleans players=0
# Done: R2022540 (2022) Mexico Open at Vidanta players=144
# Done: R2022480 (2022) Wells Fargo Championship players=156
# Done: R2022019 (2022) AT&T Byron Nelson players=156
# Done: R2022033 (2022) PGA Championship players=156
# Done: R2022021 (2022) Charles Schwab Challenge players=120
# Done: R2022023 (2022) the Memorial Tournament presented by Workday players=120
# Done: R2022032 (2022) RBC Canadian Open players=156
# Done: R2022026 (2022) U.S. Open players=156
# Done: R2022034 (2022) Travelers Championship players=156
# Done: R2022030 (2022) John Deere Classic players=156
# Done: R2022541 (2022) Genesis Scottish Open players=160
# Done: R2022518 (2022) Barbasol Championship players=156
# Done: R2022100 (2022) The Open Championship players=156
# Done: R2022472 (2022) Barracuda Championship players=156
# Done: R2022525 (2022) 3M Open players=156
# Done: R2022524 (2022) Rocket Mortgage Classic players=156
# Done: R2022013 (2022) Wyndham Championship players=156
# Done: R2022027 (2022) FedEx St. Jude Championship players=120
# Done: R2022028 (2022) BMW Championship players=68
# Done: R2022060 (2022) TOUR Championship players=29
# Done: R2023464 (2023) Fortinet Championship players=156
# Done: R2023500 (2023) Presidents Cup players=0
# Done: R2023054 (2023) Sanderson Farms Championship players=144
# Done: R2023047 (2023) Shriners Children's Open players=144
# Done: R2023527 (2023) ZOZO CHAMPIONSHIP players=78
# Done: R2023521 (2023) THE CJ CUP in South Carolina players=78
# Done: R2023528 (2023) Butterfield Bermuda Championship players=132
# Done: R2023457 (2023) World Wide Technology Championship players=132
# Done: R2023020 (2023) Cadence Bank Houston Open players=132
# Done: R2023493 (2023) The RSM Classic players=155
# Done: R2023478 (2023) Hero World Challenge players=20
# Done: R2023058 (2023) QBE Shootout players=24
# Done: R2023016 (2023) Sentry Tournament of Champions players=39
# Done: R2023006 (2023) Sony Open in Hawaii players=144
# Done: R2023002 (2023) The American Express players=156
# Done: R2023004 (2023) Farmers Insurance Open players=156
# Done: R2023005 (2023) AT&T Pebble Beach Pro-Am players=156
# Done: R2023003 (2023) WM Phoenix Open players=134
# Done: R2023007 (2023) The Genesis Invitational players=129
# Done: R2023010 (2023) The Honda Classic players=144
# Done: R2023009 (2023) Arnold Palmer Invitational presented by Mastercard players=120
# Done: R2023483 (2023) Puerto Rico Open players=120
# Done: R2023011 (2023) THE PLAYERS Championship players=144
# Done: R2023475 (2023) Valspar Championship players=144
# Done: R2023470 (2023) World Golf Championships-Dell Technologies Match Play players=64
# Done: R2023522 (2023) Corales Puntacana Championship players=120
# Done: R2023041 (2023) Valero Texas Open players=144
# Done: R2023014 (2023) Masters Tournament players=88
# Done: R2023012 (2023) RBC Heritage players=143
# Done: R2023018 (2023) Zurich Classic of New Orleans players=0
# Done: R2023540 (2023) Mexico Open at Vidanta players=144
# Done: R2023480 (2023) Wells Fargo Championship players=156
# Done: R2023019 (2023) AT&T Byron Nelson players=156
# Done: R2023033 (2023) PGA Championship players=156
# Done: R2023021 (2023) Charles Schwab Challenge players=120
# Done: R2023023 (2023) the Memorial Tournament presented by Workday players=120
# Done: R2023032 (2023) RBC Canadian Open players=156
# Done: R2023026 (2023) U.S. Open players=156
# Done: R2023034 (2023) Travelers Championship players=156
# Done: R2023524 (2023) Rocket Mortgage Classic players=156
# Done: R2023030 (2023) John Deere Classic players=156
# Done: R2023541 (2023) Genesis Scottish Open players=156
# Done: R2023518 (2023) Barbasol Championship players=156
# Done: R2023100 (2023) The Open Championship players=156
# Done: R2023472 (2023) Barracuda Championship players=156
# Done: R2023525 (2023) 3M Open players=156
# Done: R2023013 (2023) Wyndham Championship players=156
# Done: R2023027 (2023) FedEx St. Jude Championship players=70
# Done: R2023028 (2023) BMW Championship players=50
# Done: R2023060 (2023) TOUR Championship players=30
# Done: R2023543 (2023) Fortinet Championship players=156
# Done: R2023468 (2023) Ryder Cup players=0
# Done: R2023544 (2023) Sanderson Farms Championship players=144
# Done: R2023545 (2023) Shriners Children's Open players=144
# Done: R2023546 (2023) ZOZO CHAMPIONSHIP players=78
# Done: R2023547 (2023) World Wide Technology Championship players=132
# Done: R2023548 (2023) Butterfield Bermuda Championship players=132
# Done: R2023549 (2023) The RSM Classic players=155
# Done: R2023550 (2023) Hero World Challenge players=20
# Done: R2023551 (2023) Grant Thornton Invitational players=32
# Done: R2023088 (2023) PGA TOUR Q-School presented by Korn Ferry players=165
# Done: R2024016 (2024) The Sentry players=59
# Done: R2024006 (2024) Sony Open in Hawaii players=144
# Done: R2024002 (2024) The American Express players=156
# Done: R2024004 (2024) Farmers Insurance Open players=156
# Done: R2024005 (2024) AT&T Pebble Beach Pro-Am players=80
# Done: R2024003 (2024) WM Phoenix Open players=132
# Done: R2024007 (2024) The Genesis Invitational players=70
# Done: R2024540 (2024) Mexico Open at Vidanta players=132
# Done: R2024010 (2024) Cognizant Classic in The Palm Beaches players=144
# Done: R2024009 (2024) Arnold Palmer Invitational presented by Mastercard players=69
# Done: R2024483 (2024) Puerto Rico Open players=132
# Done: R2024011 (2024) THE PLAYERS Championship players=144
# Done: R2024475 (2024) Valspar Championship players=152
# Done: R2024020 (2024) Texas Children's Houston Open players=144
# Done: R2024041 (2024) Valero Texas Open players=156
# Done: R2024014 (2024) Masters Tournament players=89
# Done: R2024012 (2024) RBC Heritage players=69
# Done: R2024522 (2024) Corales Puntacana Championship players=132
# Done: R2024018 (2024) Zurich Classic of New Orleans players=0
# Done: R2024019 (2024) THE CJ CUP Byron Nelson players=156
# Done: R2024480 (2024) Wells Fargo Championship players=68
# Done: R2024553 (2024) Myrtle Beach Classic players=132
# Done: R2024033 (2024) PGA Championship players=156
# Done: R2024021 (2024) Charles Schwab Challenge players=132
# Done: R2024032 (2024) RBC Canadian Open players=156
# Done: R2024023 (2024) the Memorial Tournament presented by Workday players=73
# Done: R2024026 (2024) U.S. Open players=156
# Done: R2024034 (2024) Travelers Championship players=71
# Done: R2024524 (2024) Rocket Mortgage Classic players=156
# Done: R2024030 (2024) John Deere Classic players=156
# Done: R2024541 (2024) Genesis Scottish Open players=157
# Done: R2024518 (2024) ISCO Championship players=156
# Done: R2024100 (2024) The Open Championship players=157
# Done: R2024472 (2024) Barracuda Championship players=156
# Done: R2024525 (2024) 3M Open players=156
# Done: R2024519 (2024) Men’s Olympic Golf Competition players=60
# Done: R2024013 (2024) Wyndham Championship players=156
# Done: R2024027 (2024) FedEx St. Jude Championship players=70
# Done: R2024028 (2024) BMW Championship players=50
# Done: R2024060 (2024) TOUR Championship players=30
# Done: R2024464 (2024) Procore Championship players=144
# Done: R2024500 (2024) Presidents Cup players=0
# Done: R2024054 (2024) Sanderson Farms Championship players=132
# Done: R2024554 (2024) Black Desert Championship players=132
# Done: R2024047 (2024) Shriners Children's Open players=132
# Done: R2024527 (2024) ZOZO CHAMPIONSHIP players=78
# Done: R2024457 (2024) World Wide Technology Championship players=120
# Done: R2024528 (2024) Butterfield Bermuda Championship players=120
# Done: R2024493 (2024) The RSM Classic players=156
# Done: R2024478 (2024) Hero World Challenge players=20
# Done: R2024088 (2024) PGA TOUR Q-School presented by Korn Ferry players=170
# Done: R2024551 (2024) Grant Thornton Invitational players=32
# Done: R2025016 (2025) The Sentry players=59
# Done: R2025006 (2025) Sony Open in Hawaii players=143
# Done: R2025002 (2025) The American Express players=156
# Done: R2025004 (2025) Farmers Insurance Open players=155
# Done: R2025005 (2025) AT&T Pebble Beach Pro-Am players=80
# Done: R2025003 (2025) WM Phoenix Open players=132
# Done: R2025007 (2025) The Genesis Invitational players=72
# Done: R2025540 (2025) Mexico Open at VidantaWorld players=132
# Done: R2025010 (2025) Cognizant Classic in The Palm Beaches players=144
# Done: R2025009 (2025) Arnold Palmer Invitational presented by Mastercard players=72
# Done: R2025483 (2025) Puerto Rico Open players=132
# Done: R2025011 (2025) THE PLAYERS Championship players=144
# Done: R2025475 (2025) Valspar Championship players=154
# Done: R2025020 (2025) Texas Children's Houston Open players=153
# Done: R2025041 (2025) Valero Texas Open players=144
# Done: R2025014 (2025) Masters Tournament players=95
# Done: R2025012 (2025) RBC Heritage players=72
# Done: R2025522 (2025) Corales Puntacana Championship players=132
# Done: R2025018 (2025) Zurich Classic of New Orleans players=0
# Done: R2025019 (2025) THE CJ CUP Byron Nelson players=156
# Done: R2025480 (2025) Truist Championship players=72
# Done: R2025553 (2025) ONEflight Myrtle Beach Classic players=132
# Done: R2025033 (2025) PGA Championship players=156
# Done: R2025021 (2025) Charles Schwab Challenge players=135
# Done: R2025023 (2025) the Memorial Tournament presented by Workday players=72
# Done: R2025032 (2025) RBC Canadian Open players=156
# Done: R2025026 (2025) U.S. Open players=156
# Done: R2025034 (2025) Travelers Championship players=72
# Done: R2025524 (2025) Rocket Classic players=156
# Done: R2025030 (2025) John Deere Classic players=156
# Done: R2025541 (2025) Genesis Scottish Open players=156
# Done: R2025518 (2025) ISCO Championship players=156
# Done: R2025100 (2025) The Open Championship players=156
# Done: R2025472 (2025) Barracuda Championship players=156
# Done: R2025525 (2025) 3M Open players=156
# Done: R2025013 (2025) Wyndham Championship players=156
# Done: R2025027 (2025) FedEx St. Jude Championship players=69
# Done: R2025028 (2025) BMW Championship players=49
# Done: R2025060 (2025) TOUR Championship players=30
# Done: R2025464 (2025) Procore Championship players=144
# Done: R2025468 (2025) Ryder Cup players=0
# Done: R2025054 (2025) Sanderson Farms Championship players=132
# Done: R2025527 (2025) Baycurrent Classic players=78
# Done: R2025554 (2025) Bank of Utah Championship players=132
# Done: R2025457 (2025) World Wide Technology Championship players=120
# Done: R2025528 (2025) Butterfield Bermuda Championship players=120
# Done: R2025493 (2025) The RSM Classic players=156
# Done: R2025478 (2025) Hero World Challenge players=20
# Done: R2025088 (2025) PGA TOUR Q-School presented by Korn Ferry players=174
# Done: R2025551 (2025) Grant Thornton Invitational players=32

# %%
import pandas as pd

def tournament_course_history(df: pd.DataFrame, tournament_name: str) -> pd.DataFrame:
    """
    Pass your full results df + a tournament_key name (e.g. "Sony Open in Hawaii").
    Returns a player-level ranking dataframe with sensible handling of Txx / CUT / WD / DQ.
    """

    tdf = df[df["tournament_key"].eq(tournament_name)].copy()
    if tdf.empty:
        return pd.DataFrame()

    # --- Position parsing: "1"->1, "T58"->58, "CUT"/"WD"/"DQ"/"DNS"->NaN ---
    pos_raw = tdf["position"].astype(str).str.upper().str.strip()
    tdf["finish_pos"] = (
        pos_raw.str.replace(r"[^0-9]", "", regex=True)
        .replace("", pd.NA)
    )
    tdf["finish_pos"] = pd.to_numeric(tdf["finish_pos"], errors="coerce")

    # Made-cut flag (explicit, not "finish_pos <= 70")
    tdf["made_cut"] = ~pos_raw.isin(["CUT", "WD", "DQ", "DNS"])

    # Numeric coercions for scoring
    for c in ["total", "r1_score", "r2_score", "r3_score", "r4_score"]:
        if c in tdf.columns:
            tdf[c] = pd.to_numeric(tdf[c], errors="coerce")

    # Player historical aggregates
    player_hist = (
        tdf.groupby("playerName", dropna=False)
        .agg(
            starts=("position", "count"),                 # true appearances
            made_cuts=("made_cut", "sum"),
            cut_rate=("made_cut", "mean"),
            avg_finish=("finish_pos", "mean"),            # only where numeric
            best_finish=("finish_pos", "min"),
            avg_total=("total", "mean"),
            avg_r1=("r1_score", "mean"),
            avg_r2=("r2_score", "mean"),
            avg_r3=("r3_score", "mean"),
            avg_r4=("r4_score", "mean"),
        )
        .reset_index()
    )

    # Derived course-fit features
    player_hist["early_round_avg"] = player_hist[["avg_r1", "avg_r2"]].mean(axis=1)
    player_hist["sunday_delta"] = player_hist["avg_r4"] - player_hist["avg_r1"]

    # Course-fit score (tunable weights)
    player_hist["course_fit_score"] = (
        (100 - player_hist["avg_finish"]) * 0.45 +
        (player_hist["cut_rate"] * 100) * 0.25 +
        (70 - player_hist["early_round_avg"]) * 0.20 +
        (5 - player_hist["sunday_delta"]) * 0.10
    )

    # Recent form at this course: last 3 appearances (numeric finishes only)
    if "season_year" in tdf.columns:
        tdf["season_year"] = pd.to_numeric(tdf["season_year"], errors="coerce")
        tdf["year_rank"] = tdf.groupby("playerName")["season_year"].rank(ascending=False, method="first")
        recent = tdf[(tdf["year_rank"] <= 3) & (tdf["finish_pos"].notna())]
        recent_perf = recent.groupby("playerName")["finish_pos"].mean().rename("recent_avg_finish")
        player_hist = player_hist.merge(recent_perf, on="playerName", how="left")
        player_hist["final_score"] = (
            player_hist["course_fit_score"] * 0.7 +
            (100 - player_hist["recent_avg_finish"]) * 0.3
        )
        sort_col = "final_score"
    else:
        player_hist["final_score"] = player_hist["course_fit_score"]
        sort_col = "final_score"

    # Filter out tiny samples (optional but recommended)
    out = player_hist[player_hist["starts"] >= 2].sort_values(sort_col, ascending=False).reset_index(drop=True)
    return out

# %%
df['tournament_key'].unique()
# Out:
# array(['Hyundai Tournament of Champions', 'Sony Open in Hawaii',
#        'Humana Challenge in partnership with the Clinton Foundation',
#        'Farmers Insurance Open', 'Waste Management Phoenix Open',
#        'AT&T Pebble Beach National Pro-Am', 'Northern Trust Open',
#        'World Golf Championships-Accenture Match Play Championship',
#        'Mayakoba Golf Classic', 'The Honda Classic',
#        'Puerto Rico Open presented by seepuertorico.com',
#        'Transitions Championship',
#        'Arnold Palmer Invitational presented by MasterCard',
#        'Shell Houston Open', 'Masters Tournament', 'RBC Heritage',
#        'Valero Texas Open', 'Zurich Classic of New Orleans',
#        'Wells Fargo Championship', 'THE PLAYERS Championship',
#        'HP Byron Nelson Championship',
#        'Crowne Plaza Invitational at Colonial',
#        'the Memorial Tournament presented by Nationwide Insurance',
#        'U.S. Open', 'Travelers Championship', 'John Deere Classic',
#        'The Open Championship', 'True South Classic', 'RBC Canadian Open',
#        'Reno-Tahoe Open', 'PGA Championship', 'Wyndham Championship',
#        'The Barclays', 'BMW Championship',
#        'TOUR Championship by Coca-Cola', 'Ryder Cup',
#        'Justin Timberlake Shriners Hospitals for Children Open',
#        'Frys.com Open', 'The McGladrey Classic',
#        'PGA TOUR Qualifying Tournament',
#        'World Challenge presented by Northwestern Mutual',
#        'Franklin Templeton Shootout',
#        'Tampa Bay Championship presented by EverBank',
#        'Sanderson Farms Championship', 'Presidents Cup',
#        'Shriners Hospitals for Children Open', 'OHL Classic at Mayakoba',
#        'Northwestern Mutual World Challenge', 'Valspar Championship',
#        'Barracuda Championship', 'Hero World Challenge',
#        'Puerto Rico Open', 'World Golf Championships-Cadillac Match Play',
#        'Crowne Plaza Invitational at  Colonial', 'AT&T Byron Nelson',
#        'the Memorial Tournament presented by Nationwide',
#        'Barbasol Championship', 'The RSM Classic',
#        'CareerBuilder Challenge in partnership with the Clinton Foundation',
#        'AT&T Pebble Beach Pro-Am',
#        'World Golf Championships-Dell Match Play',
#        'Puerto Rico Open at Coco Beach', 'DEAN & DELUCA Invitational',
#        "Olympic Men's Golf Competition", 'TOUR Championship',
#        'Safeway Open', 'SBS Tournament of Champions',
#        'CareerBuilder Challenge', 'Genesis Open',
#        'Arnold Palmer Invitational presented by Mastercard',
#        'World Golf Championships-Dell Technologies Match Play',
#        'THE NORTHERN TRUST', 'THE CJ CUP @ NINE BRIDGES', 'QBE Shootout',
#        'Sentry Tournament of Champions',
#        'Corales Puntacana Resort & Club Championship', 'Houston Open',
#        'Fort Worth Invitational', 'Desert Classic',
#        'Charles Schwab Challenge', 'Rocket Mortgage Classic', '3M Open',
#        'ZOZO CHAMPIONSHIP', 'Bermuda Championship',
#        'The American Express', 'The Genesis Invitational',
#        'U.S. Open (2020)',
#        'Corales Puntacana Resort & Club Championship (2020)',
#        'THE CJ CUP @ SHADOW CREEK', 'ZOZO CHAMPIONSHIP @ SHERWOOD',
#        'Vivint Houston Open', 'Masters Tournament (2020)',
#        'Mayakoba Golf Classic presented by UNIFIN',
#        'Masters Tournament (2021)', 'Palmetto Championship at Congaree',
#        'U.S. Open (2021)', 'Fortinet Championship',
#        "Shriners Children's Open", 'THE CJ CUP @ SUMMIT',
#        'Butterfield Bermuda Championship',
#        'World Wide Technology Championship at Mayakoba',
#        'Hewlett Packard Enterprise Houston Open', 'WM Phoenix Open',
#        'Corales Puntacana Championship', 'Mexico Open at Vidanta',
#        'the Memorial Tournament presented by Workday',
#        'Genesis Scottish Open', 'FedEx St. Jude Championship',
#        'THE CJ CUP in South Carolina',
#        'World Wide Technology Championship', 'Cadence Bank Houston Open',
#        'Grant Thornton Invitational',
#        'PGA TOUR Q-School presented by Korn Ferry', 'The Sentry',
#        'Cognizant Classic in The Palm Beaches',
#        "Texas Children's Houston Open", 'THE CJ CUP Byron Nelson',
#        'Myrtle Beach Classic', 'ISCO Championship',
#        'Men’s Olympic Golf Competition', 'Procore Championship',
#        'Black Desert Championship', 'Mexico Open at VidantaWorld',
#        'Truist Championship', 'ONEflight Myrtle Beach Classic',
#        'Rocket Classic', 'Baycurrent Classic',
#        'Bank of Utah Championship'], dtype=object)

# %%
import re

def normalize_tournament_name(s: str) -> str:
    if s is None:
        return ""
    s = str(s).strip()
    s = re.sub(r"\s+", " ", s)                 # collapse whitespace
    s = re.sub(r"\(\d{4}\)$", "", s).strip()   # remove trailing "(2020)"
    s = s.lower()
    return s


ALIAS = {
    # PLAYERS
    "the players championship": [
        "the players championship", "the players"
    ],

    # SENTRY TOC
    "sentry tournament of champions": [
        "hyundai tournament of champions", "sbs tournament of champions",
        "sentry tournament of champions", "the sentry", "the sentry tournament of champions"
    ],

    # GENESIS @ riviera
    "the genesis invitational": [
        "northern trust open", "genesis open", "the genesis invitational"
    ],

    # MEMORIAL
    "the memorial tournament": [
        "the memorial tournament presented by nationwide insurance",
        "the memorial tournament presented by nationwide",
        "the memorial tournament presented by workday",
        "the memorial tournament"
    ],

    # TOUR CHAMP
    "tour championship": [
        "tour championship", "tour championship by coca-cola", "tour championship by coca cola"
    ],

    # CJ CUP
    "the cj cup": [
        "the cj cup @ nine bridges", "the cj cup @ shadow creek",
        "the cj cup @ summit", "the cj cup in south carolina",
        "the cj cup byron nelson", "the cj cup"
    ],

    # FORTINET / SAFEWAY
    "fortinet championship": [
        "safeway open", "fortinet championship", "procore championship"
    ],
}

ALIAS_REV = {}
for canon, variants in ALIAS.items():
    for v in variants:
        ALIAS_REV[normalize_tournament_name(v)] = canon


df["tournament_norm"] = df["tournament_key"].apply(normalize_tournament_name)
df["tournament_canon"] = df["tournament_norm"].map(ALIAS_REV).fillna(df["tournament_norm"])

# %%
df.to_csv('/home/zburnside/pga_prediction_model/historical_tournament_results.csv')
